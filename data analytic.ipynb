# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv(r'C:/Users/srs88/Downloads/weatherHistory/weatherHistory.csv')

# %%
data1.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data1=data.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e5804b1f83e4> in <module>
# ----> 1 data1=data.copy()
#
# NameError: name 'data' is not defined

# %%
data1.head(30)
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 0   2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1   2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2   2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3   2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4   2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5   2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6   2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7   2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8   2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9   2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# ...

# %%
data1.shape
# Out:
# (96453, 12)

# %% [markdown]
# ### Data Cleaning Part

# %%
data1.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
data1.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data1['Precip Type'].value_counts()
# Out:
# rain    85224
# snow    10712
# Name: Precip Type, dtype: int64

# %%
data1['Precip Type'].mode()
# Out:
# 0    rain
# dtype: object

# %%
data1['Precip Type'].fillna('rain',inplace=True)

# %%
data1.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
data1.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
data1.select_dtypes('object').columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Daily Summary'], dtype='object')

# %%
data1['Formatted Date'].nunique()
# Out:
# 96429

# %%
import datetime as dt

# %%
data1['Formatted Date']=pd.to_datetime(data1['Formatted Date'],utc=True)

# %%
import datetime as dt

# %%
data1['Formatted Date'].tail(30)
# Out:
# 96423   2016-09-08 16:00:00+00:00
# 96424   2016-09-08 17:00:00+00:00
# 96425   2016-09-08 18:00:00+00:00
# 96426   2016-09-08 19:00:00+00:00
# 96427   2016-09-08 20:00:00+00:00
# 96428   2016-09-08 21:00:00+00:00
# 96429   2016-09-08 22:00:00+00:00
# 96430   2016-09-08 23:00:00+00:00
# 96431   2016-09-09 00:00:00+00:00
# 96432   2016-09-09 01:00:00+00:00
# 96433   2016-09-09 02:00:00+00:00
# 96434   2016-09-09 03:00:00+00:00
# 96435   2016-09-09 04:00:00+00:00
# 96436   2016-09-09 05:00:00+00:00
# 96437   2016-09-09 06:00:00+00:00
# 96438   2016-09-09 07:00:00+00:00
# 96439   2016-09-09 08:00:00+00:00
# 96440   2016-09-09 09:00:00+00:00
# 96441   2016-09-09 10:00:00+00:00
# 96442   2016-09-09 11:00:00+00:00
# 96443   2016-09-09 12:00:00+00:00
# 96444   2016-09-09 13:00:00+00:00
# 96445   2016-09-09 14:00:00+00:00
# 96446   2016-09-09 15:00:00+00:00
# 96447   2016-09-09 16:00:00+00:00
# 96448   2016-09-09 17:00:00+00:00
# 96449   2016-09-09 18:00:00+00:00
# ...

# %%
data1['Formatted Date_days']=data1['Formatted Date'].dt.day

# %%
data1['Formatted Date_month']=data1['Formatted Date'].dt.month

# %%
data1['Formatted Date_time']=data1['Formatted Date'].dt.hour

# %%
data1.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data1.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                  float64
# Visibility (km)                         float64
# Loud Cover                              float64
# Pressure (millibars)                    float64
# Daily Summary                            object
# Formatted Date_days                       int64
# Formatted Date_month                      int64
# Formatted Date_time                       int64
# dtype: object

# %%
del data1['Formatted Date']

# %%
data1.dtypes
# Out:
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# Formatted Date_days           int64
# Formatted Date_month          int64
# Formatted Date_time           int64
# dtype: object

# %%
print(data1['Summary'].value_counts())
print(data1['Summary'].nunique())
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Windy and Mostly Cloudy                   35
# Breezy and Foggy                          35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
for col in data1.columns:
    print(col, len(data1[col].unique()))
# Out:
# Summary 27
# Precip Type 2
# Temperature (C) 7574
# Apparent Temperature (C) 8984
# Humidity 90
# Wind Speed (km/h) 2484
# Wind Bearing (degrees) 360
# Visibility (km) 949
# Loud Cover 1
# Pressure (millibars) 4979
# Daily Summary 214
# Formatted Date_days 31
# Formatted Date_month 12
# Formatted Date_time 24

# %%
data1['Summary'].value_counts().sort_values(ascending=False).head(5)
# Out:
# Partly Cloudy    31733
# Mostly Cloudy    28094
# Overcast         16597
# Clear            10890
# Foggy             7148
# Name: Summary, dtype: int64

# %%
top_5=data1['Summary'].value_counts().sort_values(ascending=False).head(5).index

# %%
top_5
# Out:
# Index(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Clear', 'Foggy'], dtype='object')

# %%
top_5=list(top_5)

# %%
import numpy as np

for categories in top_5:
    data1[categories]=np.where(data1['Summary']==categories,1,0)

# %%
data1.head()
# Out:
#          Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0  Partly Cloudy        rain         9.472222                  7.388889
# 1  Partly Cloudy        rain         9.355556                  7.227778
# 2  Mostly Cloudy        rain         9.377778                  9.377778
# 3  Partly Cloudy        rain         8.288889                  5.944444
# 4  Mostly Cloudy        rain         8.755556                  6.977778
#
#    Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0      0.89            14.1197                   251.0          15.8263
# 1      0.86            14.2646                   259.0          15.8263
# 2      0.89             3.9284                   204.0          14.9569
# 3      0.83            14.1036                   269.0          15.8263
# 4      0.83            11.0446                   259.0          15.8263
#
#    Loud Cover  Pressure (millibars)                      Daily Summary  \
# ...

# %%
data1.dtypes
# Out:
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# Formatted Date_days           int64
# Formatted Date_month          int64
# Formatted Date_time           int64
# Partly Cloudy                 int32
# Mostly Cloudy                 int32
# Overcast                      int32
# Clear                         int32
# Foggy                         int32
# dtype: object

# %%
del data1['Summary']

# %%
data1.dtypes
# Out:
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# Formatted Date_days           int64
# Formatted Date_month          int64
# Formatted Date_time           int64
# Partly Cloudy                 int32
# Mostly Cloudy                 int32
# Overcast                      int32
# Clear                         int32
# Foggy                         int32
# dtype: object

# %%
data1['Precip Type'].value_counts()
# Out:
# rain    85741
# snow    10712
# Name: Precip Type, dtype: int64

# %%
data1['Precip Type']=np.where(data1['Precip Type']=='rain',1,0)

# %%
data1['Precip Type'].value_counts()
# Out:
# 1    85741
# 0    10712
# Name: Precip Type, dtype: int64

# %%
data1['Daily Summary'].nunique()
# Out:
# 214

# %%
data1['Daily Summary'].value_counts()
# Out:
# Mostly cloudy throughout the day.                                                 20085
# Partly cloudy throughout the day.                                                  9981
# Partly cloudy until night.                                                         6169
# Partly cloudy starting in the morning.                                             5184
# Foggy in the morning.                                                              4201
#                                                                                   ...
# Overcast starting in the afternoon.                                                  24
# Partly cloudy starting overnight and breezy in the afternoon.                        24
# Mostly cloudy starting in the evening.                                               24
# Mostly cloudy starting in the morning continuing until afternoon.                    24
# Foggy starting overnight continuing until morning and breezy in the afternoon.       23
# ...

# %%
data1.head()
# Out:
#    Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 0            1         9.472222                  7.388889      0.89
# 1            1         9.355556                  7.227778      0.86
# 2            1         9.377778                  9.377778      0.89
# 3            1         8.288889                  5.944444      0.83
# 4            1         8.755556                  6.977778      0.83
#
#    Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0            14.1197                   251.0          15.8263         0.0
# 1            14.2646                   259.0          15.8263         0.0
# 2             3.9284                   204.0          14.9569         0.0
# 3            14.1036                   269.0          15.8263         0.0
# 4            11.0446                   259.0          15.8263         0.0
#
#    Pressure (millibars)                      Daily Summary  \
# ...

# %% [markdown]
# ### Ho=humidity and temprature are increased compared monthly in 10 years.
# ### Ha=not increased.

# %%
data2=data1.sample(25)

# %%
data2.head()
# Out:
#        Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 28524            1         7.222222                  4.150000      0.86
# 51944            1        19.794444                 19.794444      0.66
# 3138             0        -2.222222                 -5.938889      0.75
# 32213            1        12.777778                 12.777778      0.83
# 86117            1         1.083333                  1.083333      0.92
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 28524            17.7100                   350.0           4.9910         0.0
# 51944            12.4453                   155.0          10.3523         0.0
# 3138              9.9498                   292.0          11.2056         0.0
# 32213             8.0500                   180.0           9.9820         0.0
# 86117             3.2200                    60.0           0.0000         0.0
#
#        Pressure (millibars)  \
# 28524               1017.10
# ...

# %%
data2.corr()
# Out:
#                           Precip Type  Temperature (C)  \
# Precip Type                  1.000000         0.635847
# Temperature (C)              0.635847         1.000000
# Apparent Temperature (C)     0.655527         0.993393
# Humidity                    -0.117889        -0.604068
# Wind Speed (km/h)            0.179184         0.144258
# Wind Bearing (degrees)       0.013554        -0.403728
# Visibility (km)              0.222425         0.564298
# Loud Cover                        NaN              NaN
# Pressure (millibars)        -0.535248        -0.522548
# Formatted Date_days          0.190029         0.037929
# Formatted Date_month         0.285879         0.269788
# Formatted Date_time         -0.091639         0.104451
# Partly Cloudy               -0.213844         0.291267
# Mostly Cloudy               -0.010219        -0.074632
# Overcast                     0.272166         0.113722
# Clear                        0.128698        -0.214769
# ...

# %%
import scipy.stats as stats

# %% [markdown]
# ### Hypothesis Testing Part.

# %% [markdown]
# #### Null Hypothesis Ho: between Month and Humidity.

# %%
ttest,pvalue=stats.ttest_ind(a=data2['Formatted Date_month'], b =data2['Humidity'])
print('pvlaue', pvalue)

if pvalue<0.05:
    print('reject the null hypothesis')
else:
    print('accpet the null hypothesis')
# Out:
# pvlaue 1.4238744316122649e-10
# reject the null hypothesis

# %% [markdown]
# #### Null Hypothesis Ho: between Month and Temerature.

# %%
ttets,pvalue=stats.ttest_ind(a=data2['Formatted Date_month'], b =data2['Temperature (C)'])
print('pvalue', pvalue)

if pvalue<0.05:
    print('reject the null hypothesis')
else:
    print('accpet the null hypothesis')
# Out:
# pvalue 0.17107493970209972
# accpet the null hypothesis
